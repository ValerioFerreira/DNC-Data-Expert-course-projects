# %% [markdown]
# #1. Imports

# %% [markdown]
# ## 1.1 Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.2 Datasets

# %%
df_items = pd.read_csv('/content/DNC_order_items_dataset.csv')
df_reviews = pd.read_csv('/content/DNC_order_reviews_dataset.csv')
df_orders = pd.read_csv('/content/DNC_orders_dataset.csv')
df_products = pd.read_csv('/content/DNC_products_dataset.csv')

# %% [markdown]
# #2. EDA

# %% [markdown]
# ## 2.1 Items dataframe

# %%
df_items.head()
# Out:
#    Unnamed: 0                          order_id  order_item_id  \
# 0           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1           1  00018f77f2f0320c557190d7a144bdd3              1
# 2           2  000229ec398224ef6ca0657da4fc703e              1
# 3           3  00024acbcdf0a6daa1e931b038114c75              1
# 4           4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id   price
# 0  4244733e06e7ecb4970a6e2683c13e61   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  199.00
# 3  7634da152a4610f1595efa32f14722fc   12.99
# 4  ac6c3623068f30de03045865e4e10089  199.90

# %%
plt.figure(figsize = (12,8))

sns.countplot(df_items['order_item_id'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_items.isnull().sum()
# Out:
# Unnamed: 0       0
# order_id         0
# order_item_id    0
# product_id       0
# price            0
# dtype: int64

# %%
df_items.describe()
# Out:
#           Unnamed: 0  order_item_id          price
# count  112650.000000  112650.000000  112650.000000
# mean    56324.500000       1.197834     120.653739
# std     32519.398249       0.705124     183.633928
# min         0.000000       1.000000       0.850000
# 25%     28162.250000       1.000000      39.900000
# 50%     56324.500000       1.000000      74.990000
# 75%     84486.750000       1.000000     134.900000
# max    112649.000000      21.000000    6735.000000

# %% [markdown]
# ##2.2 Reviews dataframe

# %%
df_reviews.head()
# Out:
#    Unnamed: 0                         review_id  \
# 0           0  7bc2406110b926393aa56f80a40eba40
# 1           1  80e641a11e56f04c1ad469d5645fdfde
# 2           2  228ce5500dc1d8e020d8d1322874b6f0
# 3           3  e64fb393e7b32834bb789ff8bb30750e
# 4           4  f7c4243c7fe1938f181bec41a392bdeb
#
#                            order_id  review_score
# 0  73fc7af87114b39712e6da79b0a377eb             4
# 1  a548910a1c6147796b98fdf73dbeba33             5
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5
# 3  658677c97b385a9be170737859d3511b             5
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5

# %%
plt.figure(figsize = (12,8))

sns.countplot(df_reviews['review_score'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_reviews.isnull().sum()
# Out:
# Unnamed: 0      0
# review_id       0
# order_id        0
# review_score    0
# dtype: int64

# %%
df_reviews.describe()
# Out:
#          Unnamed: 0  review_score
# count  99224.000000  99224.000000
# mean   49611.500000      4.086421
# std    28643.645892      1.347579
# min        0.000000      1.000000
# 25%    24805.750000      4.000000
# 50%    49611.500000      5.000000
# 75%    74417.250000      5.000000
# max    99223.000000      5.000000

# %% [markdown]
# ## 2.3 Orders dataframe

# %%
df_orders.head()
# Out:
#    Unnamed: 0                          order_id  \
# 0           0  e481f51cbdc54678b7cc49136f2d6af7
# 1           1  53cdb2fc8bc7dce0b6741e2150273451
# 2           2  47770eb9100c2d0c44946d9cf07ec65d
# 3           3  949d5b44dbf5de918fe9c16f97b45f8a
# 4           4  ad21c59c0840e6cb83a9ceb5573f8159
#
#                         customer_id order_status
# 0  9ef432eb6251297304e76186b10a928d    delivered
# 1  b0830fb4747a6c6d20dea0b8c802d7ef    delivered
# 2  41ce2a54c0b03bf3443c3d931a367089    delivered
# 3  f88197465ea7920adcdbec7375364d82    delivered
# 4  8ab97904e6daea8866dbdbc4fb7aad2c    delivered

# %%
plt.figure(figsize = (12,8))

sns.countplot(df_orders['order_status'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_orders.isnull().sum()
# Out:
# Unnamed: 0      0
# order_id        0
# customer_id     0
# order_status    0
# dtype: int64

# %%
df_orders.describe()
# Out:
#          Unnamed: 0
# count  99441.000000
# mean   49720.000000
# std    28706.288396
# min        0.000000
# 25%    24860.000000
# 50%    49720.000000
# 75%    74580.000000
# max    99440.000000

# %%
df_orders.order_status.value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %% [markdown]
# ## 2.4 Products dataframe

# %%
df_products.head()
# Out:
#    Unnamed: 0                        product_id  product_category_name  \
# 0           0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1           1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2           2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3           3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4           4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_weight_g  \
# 0                 40.0                       287.0             225.0
# 1                 44.0                       276.0            1000.0
# 2                 46.0                       250.0             154.0
# 3                 27.0                       261.0             371.0
# 4                 37.0                       402.0             625.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               16.0               10.0              14.0
# ...

# %%
plt.figure(figsize = (30,8))

pd.DataFrame(df_products['product_category_name'].value_counts()[:20]).plot(kind = 'bar', figsize = (30,8))

plt.show()

# %%
df_products.isnull().sum()
# Out:
# Unnamed: 0                      0
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_products.describe()
# Out:
#          Unnamed: 0  product_name_lenght  product_description_lenght  \
# count  32951.000000         32341.000000                32341.000000
# mean   16475.000000            48.476949                  771.495285
# std     9512.278697            10.245741                  635.115225
# min        0.000000             5.000000                    4.000000
# 25%     8237.500000            42.000000                  339.000000
# 50%    16475.000000            51.000000                  595.000000
# 75%    24712.500000            57.000000                  972.000000
# max    32950.000000            76.000000                 3992.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# ...

# %% [markdown]
# # 3. Features engineering

# %%
# Removing useless info columns

dfs =  [df_products, df_orders, df_reviews, df_items]

for df in dfs:

  df.drop(columns = ['Unnamed: 0'], inplace = True)
  
df_products.dropna(inplace = True)

# %%
# Creating new columns

df_items['tot_price'] = df_items['order_item_id'] * df_items['price']
df_products['density'] = df_products['product_weight_g'] / (df_products['product_length_cm'] * df_products['product_height_cm'] * df_products['product_width_cm'])

# %%
# Merging dataframes

df1 = df_items.merge(df_reviews, on = 'order_id')
df2 = df1.merge(df_orders, on = 'order_id')
df3 = df2.merge(df_products, on = 'product_id')

# %%
df3.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id  price  tot_price  \
# 0  4244733e06e7ecb4970a6e2683c13e61   58.9       58.9
# 1  4244733e06e7ecb4970a6e2683c13e61   55.9       55.9
# 2  4244733e06e7ecb4970a6e2683c13e61   64.9       64.9
# 3  4244733e06e7ecb4970a6e2683c13e61   58.9       58.9
# 4  4244733e06e7ecb4970a6e2683c13e61   58.9       58.9
#
#                           review_id  review_score  \
# 0  97ca439bc427b48bc1cd7177abe71365             5
# 1  b11cba360bbe71410c291b764753d37f             5
# 2  af01c4017c5ab46df6cc810e069e654a             4
# 3  8304ff37d8b16b57086fa283fe0c44f8             5
# 4  426f43a82185969503fb3c86241a9535             5
#
# ...

# %%
# Wheiging reviews by relevance (2 if the product was delivered, 1 if it wasn't). We've decided that the reviews done by people who hadn't received the product yet are not 
# trustworthy, thus decreasing it's value when compared to the ones who actually received the product

df3['order_status'] = df3['order_status'].apply(lambda x: 2 if x == 'delivered' else 1)

df3['review_score'] = df3['review_score'] * df3['order_status']

# %%
#Creating additional column with the mean price of products by category

df_mpc = df3.groupby('product_category_name', as_index = False).agg({'price' : np.mean}).rename(columns = {'price' : 'mean_price_cat'})

df4 = df3.merge(df_mpc, on = 'product_category_name')

# %%
# Analysing if there are clients on the base who bought the same product more than once, giving it different reviews

df5 = df4.copy()
df5.groupby(by = ['customer_id', 'product_id']).agg({'order_id' : pd.Series.nunique})['order_id'].value_counts()

# Connclusion: no products were bought twice, on different orders, by the same costumer
# Out:
# 1    100179
# Name: order_id, dtype: int64

# %%
# Creating 'action' column, containing the following logic:

# 1 - Using 'order_item_id' to count how many times the product was bought. 
#     The most bought ones probably gets a more precise review, thus increasing it's 'action' column value
# 2 - Using 'review_score' to increase or decrease the 'action' value acording to the product review 
# 3 - Using 'price' to increase the value of the 'action', considering that higher value products, generally, are most critically reviewed
# 4 - Using 'mean_price_cat' to escalonate the products prices by category, to reduce the effects of category price differences


df5['action'] = df5['order_item_id'] * df5['review_score'] * df5['price'] / df5['mean_price_cat']

# %%
# Creating a list containing the top 1000 products with the highest 'action' score

df6 = df5.copy()

df6.sort_values('action', ascending = False, inplace = True)

top_produtos = df6.head(20000)['product_id'].tolist()

# %% [markdown]
# # 4. Modeling

# %%
# Creating a function to generate the cosine similarity matrix, as well as a list containing the index of the products

from sklearn.metrics.pairwise import cosine_similarity

def get_item_based_similarity_matrix(data, lista):
  
  product_sampled_relationship_data = data[data["product_id"].isin(lista)] \
    .pivot_table(index="customer_id", columns="product_id", values="action").fillna(0)

  return cosine_similarity(product_sampled_relationship_data.T), product_sampled_relationship_data.T.index

sim_matrix, available_items_index = get_item_based_similarity_matrix(df5, top_produtos)

# %%
# Creating a function to, once a determined item is passed, return the top n values with the highest similarity as that one

def get_n_closest(item_id, n=10):

  if item_id not in available_items_index:
   raise ValueError('Item is not available on data.')
      
  item_index = available_items_index.tolist().index(item_id)
  closest_n_item = np.argsort(-sim_matrix[item_index])[1:n]
  n_closest = []

  for item_data in zip(available_items_index[closest_n_item], sim_matrix[item_index][closest_n_item]):
    n_closest.append(item_data)
  return tuple(n_closest)

# %%
# Functioning code example

for a in list(get_n_closest('53759a2ecddad2bb87a079a1f1519f73')):
  if a[1] != 0:
    print(f'The item {a[0]} has a similarity of {a[1]*100:.2f}%')
# Out:
# The item 2ef36e1cae01b86d0ff0a2f50ff2bd53 has a similarity of 16.72%
# The item 422879e10f46682990de24d770e7f83d has a similarity of 11.44%
# The item 389d119b48cf3043d311335e499d9c6b has a similarity of 10.60%
# The item 81de659bfde3389fc8614bfba92e585a has a similarity of 10.49%
# The item 0bcc3eeca39e1064258aa1e932269894 has a similarity of 10.16%
# The item 368c6c730842d78016ad823897a372db has a similarity of 4.48%
# The item dc68ee0fcb033a1ab6714fbb5db60c15 has a similarity of 4.34%
# The item abda62f854cffdc94184e6bccadc2286 has a similarity of 3.71%
# The item b0961721fd839e9982420e807758a2a6 has a similarity of 1.39%
